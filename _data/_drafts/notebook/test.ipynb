# %%
# T까지의 숫자의 369 게임 
T = int(input())

# 369 숫자 저장 리스트 
stand_ls = [3, 6, 9]

# 출력 전 결과 저장 리스트 
store_result = []

# T가 한 자리 수일 때 참조할 리스트 
one_num = [3, 6, 9]
# T가 두 자리 수일 때 참조할 리스트 
two_num = []
# 하고 싶은 거: T 전까지만 369가 들어간 리스트 생성 
for num in range(10, 100):
    while num < T:
        f, s = num
        if f and s in stand_ls:
            store_result.append('--')
        elif f or s in stand_ls:
            store_result.append('-')
        else:
            store_result.append(num)

for num in range(100, 1001):
    while num < T:
        f, s, t = num
        if f and s and t in stand_ls:
            store_result.append('---')
        elif 


# T가 세 자리 수 일 때 참조할 리스트 








# for num in number_ls:
#     if len(num) == 1:
#         if num == 3 or 6 or 9:
#             store_result.append('-')
#         else:
#             store_result.append(num)
#     elif len(num) == 2:
#         if str(num)[0] and str(num)[1] in stand_ls:
#             store_result.append('--')
#         elif str(num)[0] or str(num)[1] in stand_ls:
#             store_result.append('-')
#     elif len(num) == 3:
#         if str(num)[0] and str(num)[1] in stand_ls:
#             store_result.append('--')
#         elif str(num)[0] or str(num)[1] in stand_ls:
#             store_result.append('-')

# for t in T:
#     if t in [3, 6, 9]:
#         store_result.append('-')
#     else:
#         store_result.append(t)
    
# for i in range(store_result): #
#     if store_result[i-1]
